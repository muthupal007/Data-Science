# %%
library(wordcloud)

# %%
library(colorspace)

# %%
words <- read.table('part-r-00000')

# %%
names(words) <- c("word","count")

# %%
words <- words[order(-words[,2]),]

# %%
wordcloud(words$word, words$count, random.order=FALSE, max.words = 250, colors=rainbow_hcl(7))
# Out:
# plot without title
